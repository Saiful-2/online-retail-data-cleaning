# %%
import pandas as pd

# %%
df = pd.read_excel("D:/DSML/Online Retail dataset/data/cleaned_online_retail.xlsx")
df.head()
# Out:
#    InvoiceNo StockCode                    Clean_Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       15.30       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       20.34       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       22.00       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       20.34       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       20.34       17850  United Kingdom

# %%
df.shape
# Out:
# (38558, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38558 entries, 0 to 38557
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          38558 non-null  int64
#  1   StockCode          38558 non-null  object
#  2   Clean_Description  38558 non-null  object
#  3   Quantity           38558 non-null  int64
#  4   InvoiceDate        38558 non-null  datetime64[ns]
#  5   UnitPrice          38558 non-null  float64
#  6   TotalPrice         38558 non-null  float64
#  7   CustomerID         38558 non-null  int64
#  8   Country            38558 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#            InvoiceNo      Quantity                    InvoiceDate  \
# count   38558.000000  38558.000000                          38558
# mean   538956.129753     14.812672  2010-12-21 02:08:30.698687744
# min    536365.000000      1.000000            2010-12-01 08:26:00
# 25%    537467.000000      2.000000            2010-12-07 10:36:00
# 50%    538852.000000      5.000000            2010-12-14 13:33:00
# 75%    540415.000000     12.000000            2011-01-07 10:47:00
# max    541686.000000  74215.000000            2011-01-20 15:42:00
# std      1580.893030    381.112275                            NaN
#
#           UnitPrice    TotalPrice    CustomerID
# count  38558.000000  38558.000000  38558.000000
# mean       3.133462     25.416517  15383.217983
# min        0.070000      0.140000  12346.000000
# 25%        1.250000      4.950000  13993.000000
# 50%        1.950000     11.800000  15358.000000
# 75%        3.750000     19.800000  17033.000000
# max      295.000000  77183.600000  18283.000000
# std        5.286768    404.356770   1771.072244

# %%
df.isnull().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Clean_Description    0
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# TotalPrice           0
# CustomerID           0
# Country              0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df['Month'] = df['InvoiceDate'].dt.month

# %%
df['Year'] = df['InvoiceDate'].dt.year

# %%
df['Check_Total'] = df['Quantity'] * df['UnitPrice']

# %%
df.head()
# Out:
#    InvoiceNo StockCode                    Clean_Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55       15.30       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       20.34       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       22.00       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       20.34       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       20.34       17850  United Kingdom
#
#    Month  Year  Check_Total
# 0     12  2010        15.30
# 1     12  2010        20.34
# 2     12  2010        22.00
# 3     12  2010        20.34
# 4     12  2010        20.34

# %%
df.to_csv("final_cleaned_online_retail.csv", index=False)
